# %%
print('This is 2nd cell')
# Out:
# This is 2nd cell

# %%
a = 13
print('a = ',a)
# Out:
# a =  13

# %%
print('This is 2nd cell')
# Out:
# This is 2nd cell

# %%
a = 13
print('a = ',a)
# Out:
# a =  13

# %%
print('This is 2nd cell')
# Out:
# This is 2nd cell

# %%
a = 13
print('a = ',a)
# Out:
# a =  13

# %%
print('This is 2nd cell')
# Out:
# This is 2nd cell

# %%
2+3
# Out:
# 5

# %%
x = 5

# %%
a ** x
# Out:
# 371293
